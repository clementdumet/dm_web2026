# %% [markdown]
# # Pandas Practice Exercises
#
# This notebook contains **simple, focused exercises** to help you practice the most important pandas functions covered in classes 02 and 03.
#
# **How to use this notebook:**
# 1. Read each exercise carefully.
# 2. Try to solve it on your own first (don't peek at hints right away!).
# 3. If you get stuck, read the **Hint** below the exercise.
# 4. If you are still stuck, look back at the class notebooks (`02-pandas.ipynb` and `03-pandas.ipynb`).
# 5. Run your code cell to check the output.
#
# **Goal:** by the end of this notebook, you should feel comfortable with:
# - Creating and inspecting DataFrames
# - Selecting columns and rows
# - Filtering data with conditions
# - Sorting and adding new columns
# - `apply()`, `groupby()` and `merge()`
#
# Take your time. There is no rush. :)

# %% [markdown]
# ## Section 0 — Warm Up: Imports and First DataFrame

# %%
# Run this cell first. It imports pandas (we will need it for everything below).
import pandas as pd

# %% [markdown]
# ### Exercise 1 — Create your first DataFrame
#
# Create a DataFrame called `students` with the following data:
#
# | name    | age | grade |
# |---------|-----|-------|
# | Alice   | 20  | 8.5   |
# | Bob     | 22  | 7.0   |
# | Charlie | 19  | 9.2   |
# | Diana   | 23  | 6.5   |
# | Ethan   | 21  | 8.8   |
#
# Then print it.
#
# **Hint:** You can build a DataFrame from a dictionary, where the keys are column names and the values are lists. Example: `pd.DataFrame({'col1': [1, 2], 'col2': ['a', 'b']})`

# %%
# TODO: Create the DataFrame and print it
students = ...

# %% [markdown]
# ## Section 1 — Inspecting a DataFrame
#
# Once you have data, the first thing is **understanding what you have**. There are a few methods for this:
# - `df.shape` → (rows, columns)
# - `df.info()` → column names, types, non-null counts
# - `df.head(n)` → first n rows (default 5)
# - `df.tail(n)` → last n rows
# - `df.describe()` → statistics for numeric columns (mean, min, max, etc.)

# %% [markdown]
# ### Exercise 2 — Inspect the `students` DataFrame
#
# Using the `students` DataFrame from Exercise 1:
# 1. Print its shape.
# 2. Print the info.
# 3. Print the first 3 rows.
# 4. Print descriptive statistics.

# %%
# TODO: 1. shape

# TODO: 2. info

# TODO: 3. first 3 rows

# TODO: 4. describe

# %% [markdown]
# ### Exercise 3 — Load a real dataset
#
# Now let's load the Canada immigration dataset (the same one from class 02).
#
# Load `Canada.xlsx` from the `03_pandas01` folder. Use:
# - `sheet_name="Canada by Citizenship"`
# - skip the first 20 rows (`skiprows=range(20)`)
#
# Save the result in a variable called `df_canada` and show the first 5 rows.

# %%
# TODO: load the dataset
df_canada = ...

# %% [markdown]
# ### Exercise 4 — Quick exploration
#
# Using `df_canada`, answer these questions in code:
# 1. How many rows and columns are there?
# 2. What are the **column names**? (Hint: `df.columns`)
# 3. What are the **data types** of each column? (Hint: `df.dtypes`)

# %%
# TODO: 1. number of rows and columns

# TODO: 2. column names

# TODO: 3. column types

# %% [markdown]
# ## Section 2 — Cleaning: drop and rename

# %% [markdown]
# ### Exercise 5 — Drop columns
#
# The columns `'AREA'`, `'REG'`, `'DEV'`, `'Type'`, `'Coverage'` are not very useful for our analysis.
#
# Use `df.drop(...)` to remove them from `df_canada`. Don't forget `axis=1` and `inplace=True`.
#
# Then show the first 3 rows to confirm the columns are gone.

# %%
# TODO: drop the columns

# %% [markdown]
# ### Exercise 6 — Rename columns
#
# The column names `'OdName'`, `'AreaName'`, `'RegName'` are not very nice.
#
# Rename them to `'Country'`, `'Continent'`, `'Region'` using `df.rename(...)`.
#
# **Hint:** You need to pass a dictionary that maps old names to new names: `{'OdName': 'Country', ...}`.

# %%
# TODO: rename columns

# %% [markdown]
# ## Section 3 — Selecting Columns

# %% [markdown]
# ### Exercise 7 — Select a single column
#
# Select **only** the `Country` column from `df_canada`.
#
# **Hint:** Two ways: `df['Country']` or `df.Country`.

# %%
# TODO

# %% [markdown]
# ### Exercise 8 — Select multiple columns
#
# Select the columns `Country`, `Continent` and the year `2010` from `df_canada`.
#
# **Hint:** When you want multiple columns, you pass a **list** inside the brackets: `df[['col1', 'col2']]`. Note the double brackets!
#
# Be careful: `2010` is an integer, not a string.

# %%
# TODO

# %% [markdown]
# ## Section 4 — Selecting Rows (this is the most important section!)

# %% [markdown]
# ### Exercise 9 — Select a row by condition with `.loc[]`
#
# Select the row where `Country == 'Brazil'` from `df_canada`.
#
# **Hint:** `df.loc[df['Country'] == 'Brazil']`

# %%
# TODO

# %% [markdown]
# ### Exercise 10 — Select rows by position with `.iloc[]`
#
# Select the rows from position 5 to 10 (inclusive of 5, exclusive of 10) from `df_canada`.
#
# **Hint:** `df.iloc[start:end]` selects rows by their integer position. So `df.iloc[5:10]`.

# %%
# TODO

# %% [markdown]
# ### Exercise 11 — Filter with one condition
#
# Select all countries from the `Continent` `'Africa'`.
#
# How many rows did you get? (Use `.shape` on the result.)

# %%
# TODO

# %% [markdown]
# ### Exercise 12 — Filter with two conditions (AND)
#
# Select all rows where:
# - The continent is `'Europe'`
# - AND the number of immigrants in `2013` was greater than 1000
#
# **Hint:** Use `&` between conditions, and **wrap each condition in parentheses**:
# ```python
# df.loc[(df['col1'] == 'A') & (df['col2'] > 100)]
# ```

# %%
# TODO

# %% [markdown]
# ### Exercise 13 — Filter with OR
#
# Select all rows where the country is `'Brazil'` OR `'Argentina'`.
#
# **Hint:** Use `|` for OR. Or use `df['Country'].isin(['Brazil', 'Argentina'])`.

# %%
# TODO

# %% [markdown]
# ## Section 5 — Adding columns and basic math

# %% [markdown]
# ### Exercise 14 — Create a `Total` column
#
# Create a new column called `Total` in `df_canada` that contains the **sum of immigrants from 1980 to 2013** for each country (sum across the year columns).
#
# **Hints:**
# - Build a list of year columns: `years = list(range(1980, 2014))`
# - `df[years].sum(axis=1)` sums across rows.
# - Assign with `df['Total'] = ...`

# %%
# TODO

# %% [markdown]
# ### Exercise 15 — Sort by Total
#
# Sort `df_canada` by the `Total` column in **descending** order. Print the top 10 countries (only the `Country` and `Total` columns).
#
# **Note:** ignore the rows where the `Country` is `'Total'` or `'Unknown'` — those are not real countries.

# %%
# TODO

# %% [markdown]
# ### Exercise 16 — Quick aggregations
#
# Using `df_canada`, answer:
# 1. What is the **average** number of immigrants in `2010` across all countries? (Hint: `.mean()` on the column.)
# 2. What is the **maximum** number of immigrants in `1995`? (Hint: `.max()`)
# 3. From which country did the **maximum** in `1995` come? (Hint: `.idxmax()` returns the index of the max — then use `.loc[]`.)

# %%
# TODO: 1

# TODO: 2

# TODO: 3

# %% [markdown]
# ## Section 6 — `apply()`
#
# `apply()` lets you run a function on every element of a column (or every row of a DataFrame). Very useful for transforming data.

# %% [markdown]
# ### Exercise 17 — `apply` on a column
#
# Go back to your `students` DataFrame from Exercise 1.
#
# Create a new column called `grade_pct` that converts `grade` (which is on a 0–10 scale) into a percentage (0–100 scale).
#
# Do it using `.apply()` with a lambda function.
#
# **Hint:** `students['grade'].apply(lambda x: x * 10)`

# %%
# TODO

# %% [markdown]
# ### Exercise 18 — `apply` with a custom function
#
# Create a new column `status` in `students` with the following rule:
# - if `grade >= 7.0` → `'approved'`
# - otherwise → `'failed'`
#
# Write a regular function (with `def`) and use `.apply()` to apply it on the `grade` column.

# %%
# TODO: define the function
def grade_status(grade):
    pass

# TODO: apply it on the column

# %% [markdown]
# ## Section 7 — `groupby()`
#
# Now we move to the Nobel Prize dataset (the same one from class 03).
#
# `groupby` lets you split data into groups and compute things per group.

# %%
# Load the dataset (run this cell)
df_prize = pd.read_csv('../04_pandas02/prize_dataset.csv')
df_prize.head()

# %% [markdown]
# ### Exercise 19 — Count prizes per category
#
# Group `df_prize` by `category` and count how many prizes there are in each category.
#
# **Hint:** `df.groupby('category').size()`

# %%
# TODO

# %% [markdown]
# ### Exercise 20 — Average prize amount per category
#
# Compute the **average** `prizeAmount` for each `category`.
#
# **Hint:** `df.groupby('category')['prizeAmount'].mean()`

# %%
# TODO

# %% [markdown]
# ### Exercise 21 — Multiple aggregations at once
#
# For each `category`, compute the **min**, **max**, and **mean** of `prizeAmount` in a single command.
#
# **Hint:** `df.groupby('category')['prizeAmount'].agg(['min', 'max', 'mean'])`

# %%
# TODO

# %% [markdown]
# ### Exercise 22 — Group by two columns
#
# Count the number of prizes per (`category`, `gender`).
#
# **Hint:** Pass a list of columns to `groupby`: `df.groupby(['category', 'gender']).size()`

# %%
# TODO

# %% [markdown]
# ## Section 8 — `merge()`
#
# Combining two DataFrames using a key column.

# %%
# Run this cell to create two small DataFrames
df_orders = pd.DataFrame({
    'OrderID': [1, 2, 3, 4, 5],
    'ProductID': ['A', 'B', 'A', 'C', 'D'],
    'Quantity': [2, 1, 3, 2, 4]
})

df_products = pd.DataFrame({
    'ProductID': ['A', 'B', 'C', 'D', 'E'],
    'ProductName': ['Widget', 'Gadget', 'Thingamajig', 'Doodad', 'Windows'],
    'Price': [25.00, 15.00, 10.00, 7.50, 0.50]
})

display(df_orders)
display(df_products)

# %% [markdown]
# ### Exercise 23 — Inner merge
#
# Merge `df_orders` and `df_products` on `ProductID` (default inner join). Save it in a variable called `df_merged`.
#
# **Hint:** `pd.merge(df_orders, df_products, on='ProductID')`

# %%
# TODO
df_merged = ...

# %% [markdown]
# ### Exercise 24 — Compute the total value per order
#
# Using `df_merged`, create a new column `TotalValue = Quantity * Price`.
#
# Then print only the `OrderID`, `ProductName`, and `TotalValue` columns.

# %%
# TODO

# %% [markdown]
# ### Exercise 25 — Outer merge to find unsold products
#
# Use `pd.merge` with `how='outer'` to find products that have **never been ordered**.
#
# **Hint:** After the outer merge, the rows for unsold products will have `NaN` in the `OrderID` column. Use `.isna()` or `.isnull()` to filter them.
#
# ```python
# df_outer = pd.merge(df_orders, df_products, on='ProductID', how='outer')
# df_outer.loc[df_outer['OrderID'].isna()]
# ```

# %%
# TODO

# %% [markdown]
# ## Bonus — Mini Challenges
#
# These exercises combine multiple concepts. Try them only after finishing the rest!

# %% [markdown]
# ### Bonus 1 — Top 5 European countries by total immigration
#
# Using `df_canada`:
# 1. Filter only countries from Europe.
# 2. Sort by `Total` (descending).
# 3. Show the top 5 (only `Country` and `Total`).

# %%
# TODO

# %% [markdown]
# ### Bonus 2 — Average immigration per continent in 2013
#
# Group `df_canada` by `Continent` and compute the **mean** of immigrants in `2013` for each continent.
#
# Sort the result from highest to lowest.

# %%
# TODO

# %% [markdown]
# ### Bonus 3 — Decade column
#
# In `df_prize`, create a new column called `decade` that contains the decade of `awardYear` (e.g. 1995 → 1990, 2003 → 2000).
#
# **Hint:** `df['awardYear'].apply(lambda y: (y // 10) * 10)`
#
# Then count how many prizes were awarded in each decade.

# %%
# TODO

# %% [markdown]
# ---
#
# **You did it!** If you completed all of the above, you have a solid grasp of pandas basics.
#
# If something didn't make sense, write down the question and bring it to the next class.
