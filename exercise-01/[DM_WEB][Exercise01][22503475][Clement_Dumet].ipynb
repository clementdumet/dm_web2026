# %% [markdown]
# # Exercise 01 - Python Programming Exercises
#
# Fill in each code cell to solve the exercise.

# %% [markdown]
# ## 1. Hello World
#
# Write a program that displays the message "Hello World" on the screen.

# %%
# Write your solution here
print("Hello World")

# %% [markdown]
# ## 2. Display Input Number
#
# Write a program that asks for a number and then displays the message: "The number entered was [number]".

# %%
# Write your solution here
print(f"The number entered was {input('Give me a Number')}")
# Out:
# the number entered was 5

# %% [markdown]
# ## 3. Sum of Two Numbers
#
# Write a program that asks for two numbers and prints their sum.

# %%
# Write your solution here
num1 = float(input("Give me a Number"))
num2 = float(input("Give me another Number"))
print(f"The sum of the two numbers is {num1 + num2}")
# Out:
# The sum of the two numbers is 3

# %% [markdown]
# ## 4. Average of Four Grades
#
# Write a program that asks for four bimonthly grades and displays the average.

# %%
# Write your solution here
grade1 = float(input("Give me the first grade"))
grade2 = float(input("Give me the second grade"))
grade3 = float(input("Give me the third grade"))
grade4 = float(input("Give me the fourth grade"))
average = (grade1 + grade2 + grade3 + grade4) / 4
print(f"The average of the four grades is {average}")

# %% [markdown]
# ## 5. Convert Meters to Centimeters
#
# Write a program that converts a length from meters to centimeters.

# %%
# Write your solution here
print(f"The length in cenimeters is {float(input('Give me the length in meters')) * 100}")
# Out:
# The length in cenimeters is 200.0

# %% [markdown]
# ## 6. Area of a Circle
#
# Write a program that asks for the radius of a circle, calculates, and displays its area.

# %%
# Write your solution here
import math


print(f"The Area of the circle is {math.pi * float(input('Give me the radius of the circle')) ** 2}")
# Out:
# The Area of the circle is 12.566370614359172

# %% [markdown]
# ## 7. Double the Area of a Square
#
# Write a program that calculates the area of a square and then shows twice this area to the user.

# %%
# Write your solution here
import math


print(f"Twice the Area of the circle is {2 * math.pi * float(input('Give me the radius of the circle')) ** 2}")

# %% [markdown]
# ## 8. Monthly Salary Calculation
#
# Write a program that asks how much you earn per hour and the number of hours worked in the month. Calculate and display your total salary for the given month.

# %%
# Write your solution here
salary = float(input("Give me the salary"))
hours = float(input("Give me the hours worked in the month"))
print(f"The salary for the month is {salary * hours}")

# %% [markdown]
# ## 9. Convert Fahrenheit to Celsius
#
# Write a program that asks for the temperature in degrees Fahrenheit, converts, and displays the temperature in degrees Celsius. Use the formula: C = 5 * ((F - 32) / 9)

# %%
# Write your solution here
print(f"the temperature in Celsius is {(float(input('Give me the temperature in Fahrenheit')) - 32) * 5 / 9}")

# %% [markdown]
# ## 10. Convert Celsius to Fahrenheit
#
# Write a program that asks for the temperature in degrees Celsius, converts, and displays it in degrees Fahrenheit.

# %%
# Write your solution here
print(f"the temperature in Fahrenheit is {float(input('Give me the temperature in Celsius')) * 9 / 5 + 32}")

# %% [markdown]
# ## 11. Mathematical Operations
#
# Write a program that asks for two integers and one real number. Calculate and display: (1) The product of twice the first number with half the second number. (2) The sum of three times the first number with the third number. (3) The third number raised to the cube.

# %%
# Write your solution here
int1 = int(input("Give me the first integer"))
int2 = int(input("Give me the second integer"))
real1 = float(input("Give me a real number"))
print(f"The product of the twice the first number and half the third number is {2 * int1 * (real1 / 2)}")

# %% [markdown]
# ## 12. Ideal Weight Calculation
#
# Given a person's height as input, write a program that calculates their ideal weight using the formula: (72.7 * height) - 58

# %%
# Write your solution 58
print(f"Your ideal weight is {(float((input('Give me your height in meters'))) * 72.7) - 58}")
# Out:
# Your ideal weight is 71.406

# %% [markdown]
# ## 13. Fish Weight Regulation
#
# João, an honest fisherman, bought a microcomputer to monitor his daily work yield. According to São Paulo's fishing regulations, any fish weight above 50 kg requires a fine of R$ 4.00 per excess kilogram. Write a program that: reads the weight of the fish, calculates and stores the excess weight (if any), computes the fine amount, and prints the results with appropriate messages.

# %%
# Write your solution here

# %% [markdown]
# ## 14. Salary Calculation with Deductions
#
# Write a program that asks how much you earn per hour and the number of hours worked in the month. Then, calculate and display: Gross salary, Social Security (8%), Union tax (5%), Income tax (11%), Net salary after deductions. Formula: + Gross Salary : $
# - Incoming Tax (11%) : $
# - Social Security (8%) : $
# - Union (5%) : $
# = Net Salary : $. Note: Net Salary = Gross Salary - Deductions.

# %%
# Write your solution here

# %% [markdown]
# ## 15. Paint Shop - Buying Large Cans
#
# Write a program for a paint shop. The program should ask for the area (in square meters) to be painted. Consider: 1 liter of paint covers 3 square meters. Paint is sold in 18-liter cans, costing R$ 80.00 each. Display the number of cans required and total price.

# %%
# Write your solution here

# %% [markdown]
# ## 16. Download Time Estimation
#
# Write a program that asks for: The file size in MB. The internet speed in Mbps. Calculate and display the approximate download time in minutes.

# %%
# Write your solution here
